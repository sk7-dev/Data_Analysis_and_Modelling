# %% [markdown]
# # **IMPORTS**

# %%
import pandas as pd 
import re
from collections import Counter
import os

# %% [markdown]
# # **LA LIGA**

# %% [markdown]
# ### **Import**

# %%
file = pd.read_csv("Datasets/el_clasico_matches_la_liga.csv")
df = pd.DataFrame(file)

# %%
df.tail()
# Out:
#      No.             Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 185  186    19 March 2023         26    Barcelona  Real Madrid     2–1 (1–1)
# 186  187  28 October 2023         11    Barcelona  Real Madrid     1–2 (1–0)
# 187  188    21 April 2024         32  Real Madrid    Barcelona     3–2 (1–1)
# 188  189  26 October 2024         11  Real Madrid    Barcelona     0–4 (0–0)
# 189  190      11 May 2025         35    Barcelona  Real Madrid           NaN
#
#                                           Goals (home)  \
# 185                        Roberto (45), Kessié (90+1)
# 186                                       Gündoğan (6)
# 187  Vinícius (18 p.), Vázquez (73), Bellingham (90+1)
# 188                                                NaN
# 189                                                NaN
#
#                                         Goals (away)
# 185                                  Araújo (9 o.g.)
# 186                            Bellingham (68, 90+2)
# 187                      Christensen (6), López (69)
# 188  Lewandowski (54, 56), Yamal (77), Raphinha (84)
# 189                                              NaN

# %% [markdown]
# ### **Change to Date Format**

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d %B %Y')
df['Year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#    No.       Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 0    1 1929-02-17          2    Barcelona  Real Madrid     1–2 (0–1)
# 1    2 1929-05-09         11  Real Madrid    Barcelona     0–1 (0–0)
# 2    3 1930-01-26          9    Barcelona  Real Madrid     1–4 (0–3)
# 3    4 1930-03-30         18  Real Madrid    Barcelona     5–1 (3–0)
# 4    5 1931-02-01          9  Real Madrid    Barcelona           0–0
#
#                           Goals (home)  \
# 0                          Parera (70)
# 1                                  NaN
# 2                          Bestit (63)
# 3  Rubio (5, 23), Lazcano (42, 68, 72)
# 4                                  NaN
#
#                                   Goals (away)  Year
# 0                              Morera (10, 55)  1929
# 1                                  Sastre (83)  1929
# 2  Rubio (10, 37), F. López (17), Lazcano (71)  1930
# 3                                 Goiburu (84)  1930
# 4                                          NaN  1931

# %%
df = df.dropna(subset=["Score (FT/HT)"])

# %%
df.shape
# Out:
# (189, 9)

# %%
df.tail()
# Out:
#      No.       Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 184  185 2022-10-16          9  Real Madrid    Barcelona     3–1 (2–0)
# 185  186 2023-03-19         26    Barcelona  Real Madrid     2–1 (1–1)
# 186  187 2023-10-28         11    Barcelona  Real Madrid     1–2 (1–0)
# 187  188 2024-04-21         32  Real Madrid    Barcelona     3–2 (1–1)
# 188  189 2024-10-26         11  Real Madrid    Barcelona     0–4 (0–0)
#
#                                           Goals (home)  \
# 184     Benzema (12), Valverde (35), Rodrygo (90+1 p.)
# 185                        Roberto (45), Kessié (90+1)
# 186                                       Gündoğan (6)
# 187  Vinícius (18 p.), Vázquez (73), Bellingham (90+1)
# 188                                                NaN
#
#                                         Goals (away)  Year
# 184                                      Torres (83)  2022
# 185                                  Araújo (9 o.g.)  2023
# 186                            Bellingham (68, 90+2)  2023
# 187                      Christensen (6), López (69)  2024
# 188  Lewandowski (54, 56), Yamal (77), Raphinha (84)  2024

# %% [markdown]
# ### **Goals**

# %%
df["Home Goals"] = df["Score (FT/HT)"].str.extract(r"(\d+)–(\d+)")[0].astype(int)
df["Away Goals"] = df["Score (FT/HT)"].str.extract(r"(\d+)–(\d+)")[1].astype(int)

# %%
df["Barcelona Goals"] = df.apply(lambda row: row["Home Goals"] if row["Home team"] == "Barcelona" else row["Away Goals"], axis=1)
df["Real Madrid Goals"] = df.apply(lambda row: row["Away Goals"] if row["Home team"] == "Barcelona" else row["Home Goals"], axis=1)

# %% [markdown]
# ### **Winner Column**

# %%
def determine_winner(row):
    if row["Barcelona Goals"] > row["Real Madrid Goals"]:
        return "Barcelona"
    elif row["Barcelona Goals"] < row["Real Madrid Goals"]:
        return "Real Madrid"
    else:
        return "Draw"

# %%
df["Winner"] = df.apply(determine_winner, axis=1)

# %% [markdown]
# ### **Venue Mapping**

# %%
venue_map = {
    "Barcelona": "Camp Nou",
    "Real Madrid": "Santiago Bernabéu Stadium"
}

# %%
df["Venue"] = df["Home team"].map(venue_map)

# %%
df.head()
# Out:
#    No.       Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 0    1 1929-02-17          2    Barcelona  Real Madrid     1–2 (0–1)
# 1    2 1929-05-09         11  Real Madrid    Barcelona     0–1 (0–0)
# 2    3 1930-01-26          9    Barcelona  Real Madrid     1–4 (0–3)
# 3    4 1930-03-30         18  Real Madrid    Barcelona     5–1 (3–0)
# 4    5 1931-02-01          9  Real Madrid    Barcelona           0–0
#
#                           Goals (home)  \
# 0                          Parera (70)
# 1                                  NaN
# 2                          Bestit (63)
# 3  Rubio (5, 23), Lazcano (42, 68, 72)
# 4                                  NaN
#
#                                   Goals (away)  Year  Home Goals  Away Goals  \
# 0                              Morera (10, 55)  1929           1           2
# 1                                  Sastre (83)  1929           0           1
# 2  Rubio (10, 37), F. López (17), Lazcano (71)  1930           1           4
# 3                                 Goiburu (84)  1930           5           1
# 4                                          NaN  1931           0           0
#
#    Barcelona Goals  Real Madrid Goals       Winner                      Venue
# 0                1                  2  Real Madrid                   Camp Nou
# 1                1                  0    Barcelona  Santiago Bernabéu Stadium
# 2                1                  4  Real Madrid                   Camp Nou
# 3                1                  5  Real Madrid  Santiago Bernabéu Stadium
# 4                0                  0         Draw  Santiago Bernabéu Stadium

# %% [markdown]
# ### **Scorers**

# %%
def scorers(df):
    df["Barcelona Scorers"] = df.apply(lambda row: row["Goals (home)"] if row["Home team"] == "Barcelona" else row["Goals (away)"], axis=1)
    df["Real Madrid Scorers"] = df.apply(lambda row: row["Goals (away)"] if row["Home team"] == "Barcelona" else row["Goals (home)"], axis=1)
    return df

# %%
df = scorers(df)

# %%
df.head()
# Out:
#    No.       Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 0    1 1929-02-17          2    Barcelona  Real Madrid     1–2 (0–1)
# 1    2 1929-05-09         11  Real Madrid    Barcelona     0–1 (0–0)
# 2    3 1930-01-26          9    Barcelona  Real Madrid     1–4 (0–3)
# 3    4 1930-03-30         18  Real Madrid    Barcelona     5–1 (3–0)
# 4    5 1931-02-01          9  Real Madrid    Barcelona           0–0
#
#                           Goals (home)  \
# 0                          Parera (70)
# 1                                  NaN
# 2                          Bestit (63)
# 3  Rubio (5, 23), Lazcano (42, 68, 72)
# 4                                  NaN
#
#                                   Goals (away)  Year  Home Goals  Away Goals  \
# 0                              Morera (10, 55)  1929           1           2
# 1                                  Sastre (83)  1929           0           1
# 2  Rubio (10, 37), F. López (17), Lazcano (71)  1930           1           4
# 3                                 Goiburu (84)  1930           5           1
# 4                                          NaN  1931           0           0
#
#    Barcelona Goals  Real Madrid Goals       Winner                      Venue  \
# 0                1                  2  Real Madrid                   Camp Nou
# 1                1                  0    Barcelona  Santiago Bernabéu Stadium
# 2                1                  4  Real Madrid                   Camp Nou
# 3                1                  5  Real Madrid  Santiago Bernabéu Stadium
# 4                0                  0         Draw  Santiago Bernabéu Stadium
#
#   Barcelona Scorers                          Real Madrid Scorers
# 0       Parera (70)                              Morera (10, 55)
# 1       Sastre (83)                                          NaN
# 2       Bestit (63)  Rubio (10, 37), F. López (17), Lazcano (71)
# 3      Goiburu (84)          Rubio (5, 23), Lazcano (42, 68, 72)
# 4               NaN                                          NaN

# %%
def extract_own_goals(row, team_col, scorers_col):
        own_goals = []
        if pd.notna(row[scorers_col]):
            scorers = str(row[scorers_col]).split(', ')
            own_goals = [scorer.split(' ')[0] for scorer in scorers if 'o.g.' in scorer]
        return ', '.join(own_goals) if own_goals else None

def split_multiple_goals(text):
    """
    Splits multiple goals by same player into separate entries.
    Example: "Lewandowski (54, 56)" -> ["Lewandowski (54)", "Lewandowski (56)"]
    """
    if pd.isna(text):
        return None
    
    results = []
    # Find patterns like "Player (min1, min2)" or "Player (min1, min2+extra)"
    matches = re.finditer(r'(\w+)\s*\(((?:\d+(?:\+\d+)?(?:\s*p\.)?(?:,\s*)?)+)\)', text)
    
    for match in matches:
        player = match.group(1)
        minutes = match.group(2).split(',')
        for minute in minutes:
            minute = minute.strip()
            if minute:  # Skip empty strings
                results.append(f"{player} ({minute})")
    
    return results

def remove_minutes(text):
    """
    Removes minutes from player names.
    Example: "Christensen (6)" -> "Christensen"
    """
    if pd.isna(text):
        return None
    
    # Replace patterns like "(number)" or "(number+number)"
    return re.sub(r'\s*\([^)]*\)', '', text)

# Example usage with a pandas DataFrame:
def transform_match_data(df):
    """
    Applies all transformations to the DataFrame
    """
    # Create new columns for own goals
    df['Real_Madrid_Own_Goals'] = df.apply(lambda x: extract_own_goals(x, 'Home team', 'Barcelona Scorers'), axis=1) 
    df['Barcelona_Own_Goals'] = df.apply(lambda x: extract_own_goals(x, 'Away team', 'Real Madrid Scorers'), axis=1)
    
    # Split multiple goals
    df['Barcelona Scorers'] = df['Barcelona Scorers'].apply(lambda x: ', '.join(split_multiple_goals(x)) if not pd.isna(x) else None)
    df['Real Madrid Scorers'] = df['Real Madrid Scorers'].apply(lambda x: ', '.join(split_multiple_goals(x)) if not pd.isna(x) else None)
    
    # Remove minutes
    df['Barcelona Scorers Clean'] = df['Barcelona Scorers'].apply(remove_minutes)
    df['Real Madrid Scorers Clean'] = df['Real Madrid Scorers'].apply(remove_minutes)
    
    return df

# %%
df = transform_match_data(df)

# %%
df
# Out:
#      No.       Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 0      1 1929-02-17          2    Barcelona  Real Madrid     1–2 (0–1)
# 1      2 1929-05-09         11  Real Madrid    Barcelona     0–1 (0–0)
# 2      3 1930-01-26          9    Barcelona  Real Madrid     1–4 (0–3)
# 3      4 1930-03-30         18  Real Madrid    Barcelona     5–1 (3–0)
# 4      5 1931-02-01          9  Real Madrid    Barcelona           0–0
# ..   ...        ...        ...          ...          ...           ...
# 184  185 2022-10-16          9  Real Madrid    Barcelona     3–1 (2–0)
# 185  186 2023-03-19         26    Barcelona  Real Madrid     2–1 (1–1)
# 186  187 2023-10-28         11    Barcelona  Real Madrid     1–2 (1–0)
# 187  188 2024-04-21         32  Real Madrid    Barcelona     3–2 (1–1)
# 188  189 2024-10-26         11  Real Madrid    Barcelona     0–4 (0–0)
#
#                                           Goals (home)  \
# 0                                          Parera (70)
# 1                                                  NaN
# 2                                          Bestit (63)
# 3                  Rubio (5, 23), Lazcano (42, 68, 72)
# 4                                                  NaN
# ..                                                 ...
# 184     Benzema (12), Valverde (35), Rodrygo (90+1 p.)
# 185                        Roberto (45), Kessié (90+1)
# 186                                       Gündoğan (6)
# 187  Vinícius (18 p.), Vázquez (73), Bellingham (90+1)
# 188                                                NaN
#
#                                         Goals (away)  Year  Home Goals  ...  \
# 0                                    Morera (10, 55)  1929           1  ...
# 1                                        Sastre (83)  1929           0  ...
# 2        Rubio (10, 37), F. López (17), Lazcano (71)  1930           1  ...
# 3                                       Goiburu (84)  1930           5  ...
# 4                                                NaN  1931           0  ...
# ..                                               ...   ...         ...  ...
# 184                                      Torres (83)  2022           3  ...
# 185                                  Araújo (9 o.g.)  2023           2  ...
# 186                            Bellingham (68, 90+2)  2023           1  ...
# 187                      Christensen (6), López (69)  2024           3  ...
# 188  Lewandowski (54, 56), Yamal (77), Raphinha (84)  2024           0  ...
#
#      Barcelona Goals  Real Madrid Goals       Winner  \
# 0                  1                  2  Real Madrid
# 1                  1                  0    Barcelona
# 2                  1                  4  Real Madrid
# 3                  1                  5  Real Madrid
# 4                  0                  0         Draw
# ..               ...                ...          ...
# 184                1                  3  Real Madrid
# 185                2                  1    Barcelona
# 186                1                  2  Real Madrid
# 187                2                  3  Real Madrid
# 188                4                  0    Barcelona
#
#                          Venue  \
# 0                     Camp Nou
# 1    Santiago Bernabéu Stadium
# 2                     Camp Nou
# 3    Santiago Bernabéu Stadium
# 4    Santiago Bernabéu Stadium
# ..                         ...
# 184  Santiago Bernabéu Stadium
# 185                   Camp Nou
# 186                   Camp Nou
# 187  Santiago Bernabéu Stadium
# 188  Santiago Bernabéu Stadium
#
#                                      Barcelona Scorers  \
# 0                                          Parera (70)
# 1                                          Sastre (83)
# 2                                          Bestit (63)
# 3                                         Goiburu (84)
# 4                                                 None
# ..                                                 ...
# 184                                        Torres (83)
# 185                        Roberto (45), Kessié (90+1)
# 186                                       Gündoğan (6)
# 187                        Christensen (6), López (69)
# 188  Lewandowski (54), Lewandowski (56), Yamal (77)...
#
#                                    Real Madrid Scorers Real_Madrid_Own_Goals  \
# 0                             Morera (10), Morera (55)                  None
# 1                                                 None                  None
# 2     Rubio (10), Rubio (37), López (17), Lazcano (71)                  None
# 3    Rubio (5), Rubio (23), Lazcano (42), Lazcano (...                  None
# 4                                                 None                  None
# ..                                                 ...                   ...
# 184     Benzema (12), Valverde (35), Rodrygo (90+1 p.)                  None
# 185                                                                     None
# 186                 Bellingham (68), Bellingham (90+2)                  None
# 187  Vinícius (18 p.), Vázquez (73), Bellingham (90+1)                  None
# 188                                               None                  None
#
#     Barcelona_Own_Goals                    Barcelona Scorers Clean  \
# 0                  None                                     Parera
# 1                  None                                     Sastre
# 2                  None                                     Bestit
# 3                  None                                    Goiburu
# 4                  None                                       None
# ..                  ...                                        ...
# 184                None                                     Torres
# 185              Araújo                            Roberto, Kessié
# 186                None                                   Gündoğan
# 187                None                         Christensen, López
# 188                None  Lewandowski, Lewandowski, Yamal, Raphinha
#
#                    Real Madrid Scorers Clean
# 0                             Morera, Morera
# 1                                       None
# 2               Rubio, Rubio, López, Lazcano
# 3    Rubio, Rubio, Lazcano, Lazcano, Lazcano
# 4                                       None
# ..                                       ...
# 184               Benzema, Valverde, Rodrygo
# 185
# 186                   Bellingham, Bellingham
# 187            Vinícius, Vázquez, Bellingham
# 188                                     None
#
# [189 rows x 21 columns]

# %% [markdown]
# ### **New Dataframe**

# %%
columns={
            "Barcelona Goals": "Barcelona_Goals", 
            "Real Madrid Goals": "Real_Madrid_Goals",
            "Barcelona Scorers Clean" : "Barcelona_Scorers",
            "Real Madrid Scorers Clean": "Real_Madrid_Scorers"
         }
new_df = df.filter(items=["Date","Year", "Venue", "Barcelona Goals", "Real Madrid Goals", "Winner", "Real_Madrid_Own_Goals", "Barcelona_Own_Goals","Barcelona Scorers Clean", "Real Madrid Scorers Clean"]).rename(columns = columns)

# %%
new_df.head()
# Out:
#         Date  Year                      Venue  Barcelona_Goals  \
# 0 1929-02-17  1929                   Camp Nou                1
# 1 1929-05-09  1929  Santiago Bernabéu Stadium                1
# 2 1930-01-26  1930                   Camp Nou                1
# 3 1930-03-30  1930  Santiago Bernabéu Stadium                1
# 4 1931-02-01  1931  Santiago Bernabéu Stadium                0
#
#    Real_Madrid_Goals       Winner Real_Madrid_Own_Goals Barcelona_Own_Goals  \
# 0                  2  Real Madrid                  None                None
# 1                  0    Barcelona                  None                None
# 2                  4  Real Madrid                  None                None
# 3                  5  Real Madrid                  None                None
# 4                  0         Draw                  None                None
#
#   Barcelona_Scorers                      Real_Madrid_Scorers
# 0            Parera                           Morera, Morera
# 1            Sastre                                     None
# 2            Bestit             Rubio, Rubio, López, Lazcano
# 3           Goiburu  Rubio, Rubio, Lazcano, Lazcano, Lazcano
# 4              None                                     None

# %%
new_df['League'] = 'La Liga'
new_df.to_csv("Datasets/Cleaned_ds/la_liga.csv", index=False)

# %% [markdown]
# # **UEFA**

# %% [markdown]
# #### **Import**

# %%
file = pd.read_csv("Datasets/el_clasico_matches_uefa.csv")
df = pd.DataFrame(file)

# %%
df.head()
# Out:
#     Season        Round     Round.1    Home team    Away team Score (FT/HT)  \
# 0  1959–60  Semi-finals   First leg  Real Madrid    Barcelona     3–1 (2–1)
# 1  1959–60  Semi-finals  Second leg    Barcelona  Real Madrid     1–3 (1–1)
# 2  1960–61  First round   First leg  Real Madrid    Barcelona     2–2 (2–1)
# 3  1960–61  First round  Second leg    Barcelona  Real Madrid     2–1 (1–0)
# 4  2001–02  Semi-finals   First leg    Barcelona  Real Madrid     0–2 (0–0)
#
#                        Goals (home)                   Goals (away)
# 0  Di Stéfano (17, 84), Puskás (28)                  Martínez (37)
# 1                       Kocsis (89)    Puskás (25, 75), Gento (68)
# 2            Mateos (3), Gento (33)        Luis Suárez (27, 87 p.)
# 3        Vergés (33), Evaristo (82)                   Canário (87)
# 4                               NaN  Zidane (55), McManaman (90+2)

# %% [markdown]
# #### **Scorers**

# %%
df = scorers(df)
df = transform_match_data(df)

# %%
df.head()
# Out:
#     Season        Round     Round.1    Home team    Away team Score (FT/HT)  \
# 0  1959–60  Semi-finals   First leg  Real Madrid    Barcelona     3–1 (2–1)
# 1  1959–60  Semi-finals  Second leg    Barcelona  Real Madrid     1–3 (1–1)
# 2  1960–61  First round   First leg  Real Madrid    Barcelona     2–2 (2–1)
# 3  1960–61  First round  Second leg    Barcelona  Real Madrid     2–1 (1–0)
# 4  2001–02  Semi-finals   First leg    Barcelona  Real Madrid     0–2 (0–0)
#
#                        Goals (home)                   Goals (away)  \
# 0  Di Stéfano (17, 84), Puskás (28)                  Martínez (37)
# 1                       Kocsis (89)    Puskás (25, 75), Gento (68)
# 2            Mateos (3), Gento (33)        Luis Suárez (27, 87 p.)
# 3        Vergés (33), Evaristo (82)                   Canário (87)
# 4                               NaN  Zidane (55), McManaman (90+2)
#
#             Barcelona Scorers                      Real Madrid Scorers  \
# 0               Martínez (37)  Stéfano (17), Stéfano (84), Puskás (28)
# 1                 Kocsis (89)     Puskás (25), Puskás (75), Gento (68)
# 2                                               Mateos (3), Gento (33)
# 3  Vergés (33), Evaristo (82)                             Canário (87)
# 4                        None            Zidane (55), McManaman (90+2)
#
#   Real_Madrid_Own_Goals Barcelona_Own_Goals Barcelona Scorers Clean  \
# 0                  None                None                Martínez
# 1                  None                None                  Kocsis
# 2                  None                None
# 3                  None                None        Vergés, Evaristo
# 4                  None                None                    None
#
#   Real Madrid Scorers Clean
# 0  Stéfano, Stéfano, Puskás
# 1     Puskás, Puskás, Gento
# 2             Mateos, Gento
# 3                   Canário
# 4         Zidane, McManaman

# %% [markdown]
# #### **Goals**

# %%
print(df.columns.tolist())
# Out:
# ['Season', 'Round', 'Round.1', 'Home team', 'Away team', 'Score\xa0(FT/HT)', 'Goals (home)', 'Goals (away)', 'Barcelona Scorers', 'Real Madrid Scorers', 'Real_Madrid_Own_Goals', 'Barcelona_Own_Goals', 'Barcelona Scorers Clean', 'Real Madrid Scorers Clean']

# %%
def goals(df):
    df["Home Goals"] = df["Score\xa0(FT/HT)"].str.extract(r"(\d+)–(\d+)")[0].astype(int)
    df["Away Goals"] = df["Score\xa0(FT/HT)"].str.extract(r"(\d+)–(\d+)")[1].astype(int)
    df["Barcelona Goals"] = df.apply(lambda row: row["Home Goals"] if row["Home team"] == "Barcelona" else row["Away Goals"], axis=1)
    df["Real Madrid Goals"] = df.apply(lambda row: row["Away Goals"] if row["Home team"] == "Barcelona" else row["Home Goals"], axis=1)
    return df

# %%
df = goals(df)

# %% [markdown]
# #### **Winner**

# %%
df["Winner"] = df.apply(determine_winner, axis=1)

# %% [markdown]
# #### **Venue Mapping**

# %%
df["Venue"] = df["Home team"].map(venue_map)

# %% [markdown]
# #### **New DF**

# %%
columns={
            "Season": "Year",
            "Barcelona Goals": "Barcelona_Goals", 
            "Real Madrid Goals": "Real_Madrid_Goals",
            "Barcelona Scorers Clean" : "Barcelona_Scorers",
            "Real Madrid Scorers Clean": "Real_Madrid_Scorers"
         }
new_df = df.filter(items=["Season", "Venue", "Barcelona Goals", "Real Madrid Goals", "Winner", "Real_Madrid_Own_Goals", "Barcelona_Own_Goals","Barcelona Scorers Clean", "Real Madrid Scorers Clean"]).rename(columns = columns)

# %%
new_df.head()
# Out:
#       Year                      Venue  Barcelona_Goals  Real_Madrid_Goals  \
# 0  1959–60  Santiago Bernabéu Stadium                1                  3
# 1  1959–60                   Camp Nou                1                  3
# 2  1960–61  Santiago Bernabéu Stadium                2                  2
# 3  1960–61                   Camp Nou                2                  1
# 4  2001–02                   Camp Nou                0                  2
#
#         Winner Real_Madrid_Own_Goals Barcelona_Own_Goals Barcelona_Scorers  \
# 0  Real Madrid                  None                None          Martínez
# 1  Real Madrid                  None                None            Kocsis
# 2         Draw                  None                None
# 3    Barcelona                  None                None  Vergés, Evaristo
# 4  Real Madrid                  None                None              None
#
#         Real_Madrid_Scorers
# 0  Stéfano, Stéfano, Puskás
# 1     Puskás, Puskás, Gento
# 2             Mateos, Gento
# 3                   Canário
# 4         Zidane, McManaman

# %%
new_df['League'] = 'UEFA Championship'
new_df.to_csv("Datasets/Cleaned_ds/uefa.csv", index=False)

# %% [markdown]
# # **COPA DEL REY**

# %%
file = pd.read_csv("Datasets/el_clasico_matches_copa_del_rey.csv")
df = pd.DataFrame(file)

# %%
df.tail()
# Out:
#      Season        Round     Round.1     Home team    Away team Score (FT/HT)  \
# 32  2013–14        Final       Final  Real Madrid*    Barcelona     2–1 (1–0)
# 33  2018–19  Semi-finals   First leg     Barcelona  Real Madrid     1–1 (0–1)
# 34  2018–19  Semi-finals  Second leg   Real Madrid    Barcelona     0–3 (0–0)
# 35  2022–23  Semi-finals   First leg   Real Madrid    Barcelona     0–1 (0–1)
# 36  2022–23  Semi-finals  Second leg     Barcelona  Real Madrid     0–4 (0–1)
#
#                 Goals (home)                              Goals (away)
# 32  Di María (11), Bale (85)                               Bartra (69)
# 33               Malcom (57)                               Vázquez (6)
# 34                       NaN   L. Suárez (50, 73 p.), Varane (69 o.g.)
# 35                       NaN                         Militão (26 o.g.)
# 36                       NaN  Vinícius (45+1), Benzema (50, 58 p., 80)

# %%
df['Season'].iloc[10:20]
# Out:
# 10    1954
# 11    1957
# 12    1957
# 13    1959
# 14    1959
# 15    1962
# 16    1962
# 17    1968
# 18    1970
# 19    1970
# Name: Season, dtype: int64

# %%
def clean_year(year):
    if isinstance(year, str):
        # Replace any non-standard dashes with a normal hyphen
        year = year.replace('â€“', '-').replace('–', '-').replace('—', '-')
        
        # If there's a hyphen, take the second part and format it correctly
        if '-' in year:
            year = year.split('-')[1]  # Take the second part (e.g., '59' from '1958-59')
            if len(year) == 2:  # If it's a two-digit year like '59'
                return '19' + year  # Convert '59' to '1959'
    
    return year  # Return the original value if no hyphen is found

# Apply the function
df['Season'] = df['Season'].apply(clean_year)

# Convert to integer type if needed
df['Season'] = df['Season'].astype(int)

# %%
df = scorers(df)
df = transform_match_data(df)

# %%
df = goals(df)

# %%
df["Winner"] = df.apply(determine_winner, axis=1)

# %%
df["Venue"] = df["Home team"].map(venue_map)

# %%
columns={
            "Season": "Year",
            "Barcelona Goals": "Barcelona_Goals", 
            "Real Madrid Goals": "Real_Madrid_Goals",
            "Barcelona Scorers Clean" : "Barcelona_Scorers",
            "Real Madrid Scorers Clean": "Real_Madrid_Scorers"
         }
new_df = df.filter(items=["Season", "Venue", "Barcelona Goals", "Real Madrid Goals", "Winner", "Real_Madrid_Own_Goals", "Barcelona_Own_Goals","Barcelona Scorers Clean", "Real Madrid Scorers Clean"]).rename(columns = columns)

# %%
new_df.head()
# Out:
#    Year                      Venue  Barcelona_Goals  Real_Madrid_Goals  \
# 0  1916                   Camp Nou                2                  1
# 1  1916  Santiago Bernabéu Stadium                1                  4
# 2  1916  Santiago Bernabéu Stadium                6                  6
# 3  1916  Santiago Bernabéu Stadium                2                  4
# 4  1926  Santiago Bernabéu Stadium                5                  1
#
#         Winner Real_Madrid_Own_Goals Barcelona_Own_Goals  \
# 0    Barcelona                  None                None
# 1  Real Madrid                  None                None
# 2         Draw                  None                None
# 3  Real Madrid                  None                None
# 4    Barcelona                  None                None
#
#                                    Barcelona_Scorers  \
# 0                                Alcántara, Martínez
# 1                                           Martínez
# 2  Alcántara, Alcántara, Alcántara, Mallorquí, Ba...
# 3                                 Martínez, Martínez
# 4      Samitier, Samitier, Samitier, Samitier, Piera
#
#                       Real_Madrid_Scorers
# 0                                   Petit
# 1                                   Petit
# 2            Belaunde, Belaunde, Belaunde
# 3  Bernabéu, Zabalo, Aranguren, Aranguren
# 4                               Monjardín

# %%
new_df['League'] = 'Copa Del Rey'
new_df.to_csv("Datasets/Cleaned_ds/copa_del_rey.csv", index=False)

# %% [markdown]
# # **COPA DE LA LIGA**

# %%
file = pd.read_csv("Datasets/el_clasico_matches_copa_de_la_liga.csv")
df = pd.DataFrame(file)

# %%
df.head()
# Out:
#     Season           Round     Round.1    Home team    Away team  \
# 0  1982–83           Final   First leg  Real Madrid    Barcelona
# 1  1982–83           Final  Second leg    Barcelona  Real Madrid
# 2  1984–85  Quarter-finals   First leg    Barcelona  Real Madrid
# 3  1984–85  Quarter-finals  Second leg  Real Madrid    Barcelona
# 4  1985–86    Second round   First leg    Barcelona  Real Madrid
#
#         Score (FT/HT)                      Goals (home)  \
# 0           2–2 (0–0)  Del Bosque (62), Juanito (68 p.)
# 1           2–1 (2–0)   Maradona (19 p.), Alexanko (25)
# 2           2–2 (2–0)            Clos (40), Marcos (44)
# 3  1–1 (0–0) (4–1 p.)                      Valdano (83)
# 4           2–2 (1–1)         Clos (24), Archibald (50)
#
#                    Goals (away)
# 0  Carrasco (53), Maradona (57)
# 1               Santillana (80)
# 2    Valdano (67), Juanito (75)
# 3                Moratalla (57)
# 4      Pardeza (36), Cholo (52)

# %%
df = scorers(df)
df = transform_match_data(df)
df = goals(df)
df["Winner"] = df.apply(determine_winner, axis=1)
df["Venue"] = df["Home team"].map(venue_map)

# %%
columns={
            "Season": "Date",
            "Barcelona Goals": "Barcelona_Goals", 
            "Real Madrid Goals": "Real_Madrid_Goals",
            "Barcelona Scorers Clean" : "Barcelona_Scorers",
            "Real Madrid Scorers Clean": "Real_Madrid_Scorers"
         }
new_df = df.filter(items=["Season", "Venue", "Barcelona Goals", "Real Madrid Goals", "Winner", "Real_Madrid_Own_Goals", "Barcelona_Own_Goals","Barcelona Scorers Clean", "Real Madrid Scorers Clean"]).rename(columns = columns)

# %%
new_df['League'] = 'Copa De La Liga'
new_df.to_csv("Datasets/Cleaned_ds/copa_de_la_liga.csv", index=False)

# %% [markdown]
# # **SUPERCOPA**

# %%
file = pd.read_csv("Datasets/el_clasico_matches_supercopa.csv")
df = pd.DataFrame(file)

# %%
df.head()
# Out:
#     Season       Round    Home team    Away team Score (FT/HT)  \
# 0  1988–89   First leg  Real Madrid    Barcelona     2–0 (0–0)
# 1  1988–89  Second leg    Barcelona  Real Madrid     2–1 (1–1)
# 2  1990–91   First leg    Barcelona  Real Madrid     0–1 (0–0)
# 3  1990–91  Second leg  Real Madrid    Barcelona     4–1 (2–1)
# 4  1993–94   First leg  Real Madrid    Barcelona     3–1 (1–1)
#
#                                         Goals (home)     Goals (away)
# 0                     Míchel (51), Hugo Sánchez (78)              NaN
# 1                                    Bakero (37, 78)  Butragueño (15)
# 2                                                NaN      Míchel (55)
# 3  Butragueño (21, 44), Hugo Sánchez (56), Aragón...  Goikoetxea (20)
# 4                    Alfonso (33, 85), Zamorano (55)   Stoichkov (15)

# %%
df = scorers(df)
df = transform_match_data(df)
df = goals(df)
df["Winner"] = df.apply(determine_winner, axis=1)
df["Venue"] = df["Home team"].map(venue_map)

# %%
columns={
            "Season": "Year",
            "Barcelona Goals": "Barcelona_Goals", 
            "Real Madrid Goals": "Real_Madrid_Goals",
            "Barcelona Scorers Clean" : "Barcelona_Scorers",
            "Real Madrid Scorers Clean": "Real_Madrid_Scorers"
         }
new_df = df.filter(items=["Season", "Venue", "Barcelona Goals", "Real Madrid Goals", "Winner", "Real_Madrid_Own_Goals", "Barcelona_Own_Goals","Barcelona Scorers Clean", "Real Madrid Scorers Clean"]).rename(columns = columns)

# %%
new_df['League'] = 'Supercopa'
new_df.to_csv("Datasets/Cleaned_ds/supercopa.csv", index=False)

# %% [markdown]
# # **Dates Dataset**

# %%
file = pd.read_csv("Datasets/Dates_df.csv", encoding="ISO-8859-1")
df = pd.DataFrame(file)

# %%
df = df.dropna(subset=["Result"])

# %%
df.head()
# Out:
#                 Date          Home team          Away team Result
# 0  Sat, Jan 11, 2025        Real Madrid          Barcelona  02:05
# 1  Fri, Oct 25, 2024  Real Madrid  (2.)    Barcelona  (1.)  00:04
# 2  Sat, Apr 20, 2024  Real Madrid  (1.)    Barcelona  (2.)  03:02
# 3  Sat, Jan 13, 2024        Real Madrid          Barcelona  04:01
# 4  Fri, Oct 27, 2023    Barcelona  (4.)  Real Madrid  (2.)  01:02

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%a, %b %d, %Y').dt.strftime('%d-%m-%Y')

# %%
df['Year'] = pd.to_datetime(df['Date'], format='%d-%m-%Y').dt.year

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")
df["Date"] = df["Date"] + pd.Timedelta(days=1)
df["Date"] = df["Date"].dt.strftime("%d-%m-%Y")

# %%
df = pd.DataFrame(df)

# Remove bracketed values from Home team and Away team
df['Home team'] = df['Home team'].apply(lambda x: re.sub(r'\s*\(.*?\)', '', x))
df['Away team'] = df['Away team'].apply(lambda x: re.sub(r'\s*\(.*?\)', '', x))

# Convert Result format from 02:05 to 2-5
df[['Home Score', 'Away Score']] = df['Result'].str.split(':', expand=True)
df['Home Score'] = df['Home Score'].astype(int)
df['Away Score'] = df['Away Score'].astype(int)
df['Result'] = df['Home Score'].astype(str) + '-' + df['Away Score'].astype(str)

# Determine the winner
def get_winner(row):
    if row['Home Score'] > row['Away Score']:
        return row['Home team']
    elif row['Home Score'] < row['Away Score']:
        return row['Away team']
    else:
        return 'Draw'

df['Winner'] = df.apply(get_winner, axis=1)

# %%
df.head()
# Out:
#          Date    Home team    Away team Result  Year  Home Score  Away Score  \
# 0  12-01-2025  Real Madrid    Barcelona    2-5  2025           2           5
# 1  26-10-2024  Real Madrid    Barcelona    0-4  2024           0           4
# 2  21-04-2024  Real Madrid    Barcelona    3-2  2024           3           2
# 3  14-01-2024  Real Madrid    Barcelona    4-1  2024           4           1
# 4  28-10-2023    Barcelona  Real Madrid    1-2  2023           1           2
#
#         Winner
# 0    Barcelona
# 1    Barcelona
# 2  Real Madrid
# 3  Real Madrid
# 4  Real Madrid

# %%
df["Barcelona Goals"] = df.apply(lambda row: row["Home Score"] if row["Home team"] == "Barcelona" else row["Away Score"], axis=1)
df["Real Madrid Goals"] = df.apply(lambda row: row["Home Score"] if row["Home team"] == "Real Madrid" else row["Away Score"], axis=1)

# %%
df.head()
# Out:
#          Date    Home team    Away team Result  Year  Home Score  Away Score  \
# 0  12-01-2025  Real Madrid    Barcelona    2-5  2025           2           5
# 1  26-10-2024  Real Madrid    Barcelona    0-4  2024           0           4
# 2  21-04-2024  Real Madrid    Barcelona    3-2  2024           3           2
# 3  14-01-2024  Real Madrid    Barcelona    4-1  2024           4           1
# 4  28-10-2023    Barcelona  Real Madrid    1-2  2023           1           2
#
#         Winner  Barcelona Goals  Real Madrid Goals
# 0    Barcelona                5                  2
# 1    Barcelona                4                  0
# 2  Real Madrid                2                  3
# 3  Real Madrid                1                  4
# 4  Real Madrid                1                  2

# %%
df["Winner"].unique()
# Out:
# array(['Barcelona', 'Real Madrid', 'Draw', 'FC Barcelona', 'Madrid FC'],
#       dtype=object)

# %%
df["Winner"] = df["Winner"].replace("FC Barcelona", "Barcelona")
df["Winner"] = df["Winner"].replace("Madrid FC", "Real Madrid")

# %%
columns={
            "Barcelona Goals": "Barcelona_Goals", 
            "Real Madrid Goals": "Real_Madrid_Goals",
         }
new_df = df.filter(items=["Date","Year", "Barcelona Goals", "Real Madrid Goals", "Winner"]).rename(columns = columns)

# %%
new_df.head()
# Out:
#          Date  Year  Barcelona_Goals  Real_Madrid_Goals       Winner
# 0  12-01-2025  2025                5                  2    Barcelona
# 1  26-10-2024  2024                4                  0    Barcelona
# 2  21-04-2024  2024                2                  3  Real Madrid
# 3  14-01-2024  2024                1                  4  Real Madrid
# 4  28-10-2023  2023                1                  2  Real Madrid

# %%
new_df['Date'] = pd.to_datetime(new_df['Date'], format='%d-%m-%Y')
# Sort DataFrame by Date (Ascending)
df_sorted = new_df.sort_values(by='Date', ascending=True).reset_index(drop=True)

# %%
df_sorted.head()
# Out:
#         Date  Year  Barcelona_Goals  Real_Madrid_Goals       Winner
# 0 1902-05-13  1902                1                  1    Barcelona
# 1 1916-03-26  1916                1                  1    Barcelona
# 2 1916-04-02  1916                1                  1  Real Madrid
# 3 1916-04-13  1916                6                  6         Draw
# 4 1916-04-15  1916                2                  2  Real Madrid

# %%
df_sorted.to_csv("Datasets/dates_df_cleaned.csv", index=False)

# %% [markdown]
# # **ALL GAMES**

# %%
import pandas as pd
import os

def combine_csv_files(directory_path, output_file):
    dfs = []
    for csv_file in os.listdir(directory_path):
        if csv_file.endswith(".csv"):
            file_path = os.path.join(directory_path, csv_file)
            try:
                df = pd.read_csv(file_path)  # Change encoding
                df['source_file'] = csv_file.replace('.csv', '')  # Add source column
                dfs.append(df)
            except UnicodeDecodeError:
                print(f"Encoding error in file: {csv_file}. Skipping it.")

    combined_df = pd.concat(dfs, ignore_index=True)
    combined_df.to_csv(output_file, index=False)

# Call function
directory = "Datasets/Cleaned_ds"
output_file = "Datasets/combined_soccer_data.csv"
combine_csv_files(directory, output_file)

# %% [markdown]
# # **Add Dates**

# %%
file1 = pd.read_csv("Datasets/dates_df_cleaned.csv")
file2 = pd.read_csv("Datasets/combined_soccer_data.csv")
df1 = pd.DataFrame(file1)
df2 = pd.DataFrame(file2)

# %%
df1.head(4)
# Out:
#          Date  Year  Barcelona_Goals  Real_Madrid_Goals       Winner
# 0  12-01-2025  2025                5                  2    Barcelona
# 1  26-10-2024  2024                4                  0    Barcelona
# 2  21-04-2024  2024                2                  3  Real Madrid
# 3  14-01-2024  2024                1                  4  Real Madrid

# %%
df2.head(4)
# Out:
#    Year                      Venue  Barcelona_Goals  Real_Madrid_Goals  \
# 0  1916                   Camp Nou                2                  1
# 1  1916  Santiago Bernabéu Stadium                1                  4
# 2  1916  Santiago Bernabéu Stadium                6                  6
# 3  1916  Santiago Bernabéu Stadium                2                  4
#
#         Winner Real_Madrid_Own_Goals Barcelona_Own_Goals  \
# 0    Barcelona                   NaN                 NaN
# 1  Real Madrid                   NaN                 NaN
# 2         Draw                   NaN                 NaN
# 3  Real Madrid                   NaN                 NaN
#
#                                    Barcelona_Scorers  \
# 0                                Alcántara, Martínez
# 1                                           Martínez
# 2  Alcántara, Alcántara, Alcántara, Mallorquí, Ba...
# 3                                 Martínez, Martínez
#
#                       Real_Madrid_Scorers        League   source_file Date
# 0                                   Petit  Copa Del Rey  copa_del_rey  NaN
# 1                                   Petit  Copa Del Rey  copa_del_rey  NaN
# 2            Belaunde, Belaunde, Belaunde  Copa Del Rey  copa_del_rey  NaN
# 3  Bernabéu, Zabalo, Aranguren, Aranguren  Copa Del Rey  copa_del_rey  NaN

# %%
df1.shape
# Out:
# (259, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               259 non-null    object
#  1   Year               259 non-null    int64
#  2   Barcelona_Goals    259 non-null    int64
#  3   Real_Madrid_Goals  259 non-null    int64
#  4   Winner             259 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 10.2+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   259 non-null    int64
#  1   Venue                  254 non-null    object
#  2   Barcelona_Goals        259 non-null    int64
#  3   Real_Madrid_Goals      259 non-null    int64
#  4   Winner                 259 non-null    object
#  5   Real_Madrid_Own_Goals  8 non-null      object
#  6   Barcelona_Own_Goals    5 non-null      object
#  7   Barcelona_Scorers      195 non-null    object
#  8   Real_Madrid_Scorers    188 non-null    object
#  9   League                 259 non-null    object
#  10  source_file            259 non-null    object
#  11  Date                   190 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 24.4+ KB

# %%
df2.shape
# Out:
# (259, 12)

# %%
merged_df = df2.merge(df1, on=["Year", "Barcelona_Goals", "Real_Madrid_Goals", "Winner"], how="right")

# %%
merged_df = df2.merge(df1,
                      on=['Year', 'Barcelona_Goals', 'Real_Madrid_Goals'], 
                      how='left')

# %%
merged_df.shape
# Out:
# (284, 14)

# %%
merged_df.head()
# Out:
#    Year                      Venue  Barcelona_Goals  Real_Madrid_Goals  \
# 0  2025  Santiago Bernabéu Stadium                5                  2
# 1  2024  Santiago Bernabéu Stadium                4                  0
# 2  2024  Santiago Bernabéu Stadium                2                  3
# 3  2024  Santiago Bernabéu Stadium                1                  4
# 4  2023                   Camp Nou                1                  2
#
#         Winner Real_Madrid_Own_Goals Barcelona_Own_Goals  \
# 0    Barcelona                   NaN                 NaN
# 1    Barcelona                   NaN                 NaN
# 2  Real Madrid                   NaN                 NaN
# 3  Real Madrid                   NaN                 NaN
# 4  Real Madrid                   NaN                 NaN
#
#                            Barcelona_Scorers     Real_Madrid_Scorers  \
# 0           Yamal, Raphinha, Raphinha, Balde         Mbappé, Rodrygo
# 1  Lewandowski, Lewandowski, Yamal, Raphinha                     NaN
# 2                         Christensen, López     Vázquez, Bellingham
# 3                                Lewandowski                 Rodrygo
# 4                                   Gündoğan  Bellingham, Bellingham
#
#       League source_file      Date_x      Date_y
# 0  Supercopa   supercopa         NaN  12-01-2025
# 1    La Liga     la_liga  26-10-2024  26-10-2024
# 2    La Liga     la_liga  21-04-2024  21-04-2024
# 3  Supercopa   supercopa         NaN  14-01-2024
# 4    La Liga     la_liga  28-10-2023  28-10-2023

# %%
merged_df.to_csv("Datasets/Cleaned_ds/merged_df.csv", index=False)

# %%
def merge_clasico_data(df1, df2):
    # Rename columns to ensure consistency
    df1 = df1.rename(columns={
        'Barcelona_Goals': 'Barcelona_Goals',
        'Real_Madrid_Goals': 'Real_Madrid_Goals'
    })
    
    # Create a match identifier using all common columns
    match_columns = ['Year', 'Barcelona_Goals', 'Real_Madrid_Goals', 'Winner']
    
    # Create match signatures for both dataframes
    df1['match_signature'] = df1[match_columns].astype(str).agg('-'.join, axis=1)
    df2['match_signature'] = df2[match_columns].astype(str).agg('-'.join, axis=1)
    
    # Create a mapping dictionary from match signature to date
    date_mapping = pd.Series(df1['Date'].values, index=df1['match_signature']).to_dict()
    
    # Add Date column to df2
    df2['Date'] = df2['match_signature'].map(date_mapping)
    
    # Drop the temporary match signature column
    df2 = df2.drop('match_signature', axis=1)
    
    # Sort the dataframe by date
    df2 = df2.sort_values('Date', ascending=False)
    
    return df2


merged_df = merge_clasico_data(df1, df2)

# %%
merged_df.shape
# Out:
# (259, 12)

# %%
merged_df.head()
# Out:
#      Year                      Venue  Barcelona_Goals  Real_Madrid_Goals  \
# 155  1987                   Camp Nou                3                  2
# 151  1984                   Camp Nou                3                  2
# 142  1980                   Camp Nou                2                  1
# 174  1995  Santiago Bernabéu Stadium                1                  1
# 106  1962  Santiago Bernabéu Stadium                0                  2
#
#           Winner Real_Madrid_Own_Goals Barcelona_Own_Goals  \
# 155    Barcelona                   NaN                 NaN
# 151    Barcelona                   NaN                 NaN
# 142    Barcelona                   NaN                 NaN
# 174         Draw                   NaN                 NaN
# 106  Real Madrid                   NaN                 NaN
#
#              Barcelona_Scorers  Real_Madrid_Scorers   League source_file  \
# 155  Lineker, Lineker, Lineker              Valdano  La Liga     la_liga
# 151     Gerardo, Migueli, Vigo  Sanchís, Butragueño  La Liga     la_liga
# 142            Schuster, Quini              Juanito  La Liga     la_liga
# 174                      Roger                 Raúl  La Liga     la_liga
# 106                        NaN     Stéfano, Stéfano  La Liga     la_liga
#
#            Date
# 155  31-01-1987
# 151  30-12-1984
# 142  30-11-1980
# 174  30-09-1995
# 106  30-09-1962
