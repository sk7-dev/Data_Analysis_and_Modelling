# %%
import pandas as pd

# %% [markdown]
# ### Script to Identify Tables

# %%
def explore_tables():
    url = 'https://en.wikipedia.org/wiki/List_of_El_Cl%C3%A1sico_matches'
    tables = pd.read_html(url)
    print(f"Total number of tables found: {len(tables)}")
    for i, table in enumerate(tables):
        print(f"\nTable {i}:")
        print("Shape:", table.shape)
        print("Columns:", list(table.columns))
        print("First few rows:")
        print(table.head(2))  # Show first 2 rows of each table
        print("-" * 80)  # Separator for better readability
try:
    explore_tables()
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ### Script to scrape

# %%
def scrape_el_clasico_data():
    # URL of the Wikipedia page
    url = 'https://en.wikipedia.org/wiki/List_of_El_Cl%C3%A1sico_matches'
    tables = pd.read_html(url)
    # Reference the table using the table index
    matches_df = tables[8]
    # Remove any '[note #]' references from cells
    matches_df = matches_df.replace(r'\[.*\]', '', regex=True)
    return matches_df
try:
    el_clasico_data = scrape_el_clasico_data()
    print(el_clasico_data.head())
    # Save to CSV
    el_clasico_data.to_csv('el_clasico/Datasets/el_clasico_matches_copa_de_la_liga.csv', index=False)
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Out:
# Total number of tables found: 40
#
# Table 0:
# Shape: (190, 8)
# Columns: ['No.', 'Date', 'Matchweek', 'Home team', 'Away team', 'Score (FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#    No.              Date  Matchweek    Home team    Away team Score (FT/HT)  \
# 0    1  17 February 1929          2    Barcelona  Real Madrid     1–2 (0–1)
# 1    2        9 May 1929         11  Real Madrid    Barcelona     0–1 (0–0)
#
#   Goals (home)     Goals (away)
# 0  Parera (70)  Morera (10, 55)
# 1          NaN      Sastre (83)
# --------------------------------------------------------------------------------
#
# Table 1:
# Shape: (10, 6)
# Columns: [0, 1, 2, 3, 4, 5]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 79 Draws 35 Barcelona wins 75...
# 1                                   Real Madrid wins
#
#                                                    1    2    3    4    5
# 0  Team Home wins Home draws Home losses GF GA Re...  NaN  NaN  NaN  NaN
# 1                                                 79  NaN  NaN  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 2:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0   1
# 0  Real Madrid wins  79
# 1             Draws  35
# --------------------------------------------------------------------------------
#
# Table 3:
# Shape: (2, 6)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses', 'GF', 'GA']
# First few rows:
#           Team  Home wins  Home draws  Home losses   GF   GA
# 0  Real Madrid         56          15           24  191  122
# 1    Barcelona         51          20           23  183  113
# --------------------------------------------------------------------------------
#
# Table 4:
# Shape: (37, 8)
# Columns: ['Season', 'Round', 'Round.1', 'Home team', 'Away team', 'Score\xa0(FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#   Season        Round     Round.1    Home team    Away team Score (FT/HT)  \
# 0   1916  Semi-finals   First leg    Barcelona  Real Madrid     2–1 (1–1)
# 1   1916  Semi-finals  Second leg  Real Madrid    Barcelona     4–1 (2–1)
#
#                            Goals (home)       Goals (away)
# 0         Alcántara (39), Martínez (85)  Petit (17)[9][10]
# 1  Bernabéu (35 p., 40, 60), Petit (80)      Martínez (20)
# --------------------------------------------------------------------------------
#
# Table 5:
# Shape: (10, 5)
# Columns: [0, 1, 2, 3, 4]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 13 Draws 8 Barcelona wins 16 ...
# 1                                   Real Madrid wins
#
#                                                    1    2    3    4
# 0  Team Home wins Home draws Home losses Other ve...  NaN  NaN  NaN
# 1                                                 13  NaN  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 6:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0   1
# 0  Real Madrid wins  13
# 1             Draws   8
# --------------------------------------------------------------------------------
#
# Table 7:
# Shape: (2, 5)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses', 'Other venue wins']
# First few rows:
#           Team  Home wins  Home draws Home losses  Other venue wins
# 0  Real Madrid          5           5   6[note 1]                 4
# 1    Barcelona          7           3           4                 3
# --------------------------------------------------------------------------------
#
# Table 8:
# Shape: (6, 8)
# Columns: ['Season', 'Round', 'Round.1', 'Home team', 'Away team', 'Score\xa0(FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#     Season  Round     Round.1    Home team    Away team Score (FT/HT)  \
# 0  1982–83  Final   First leg  Real Madrid    Barcelona     2–2 (0–0)
# 1  1982–83  Final  Second leg    Barcelona  Real Madrid     2–1 (2–0)
#
#                        Goals (home)                  Goals (away)
# 0  Del Bosque (62), Juanito (68 p.)  Carrasco (53), Maradona (57)
# 1   Maradona (19 p.), Alexanko (25)               Santillana (80)
# --------------------------------------------------------------------------------
#
# Table 9:
# Shape: (10, 4)
# Columns: [0, 1, 2, 3]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 0 Draws 4 Barcelona wins 2 Re...
# 1                                   Real Madrid wins
#
#                                                    1    2    3
# 0  Team Home wins Home draws Home losses Real Mad...  NaN  NaN
# 1                                                  0  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 10:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0  1
# 0  Real Madrid wins  0
# 1             Draws  4
# --------------------------------------------------------------------------------
#
# Table 11:
# Shape: (2, 4)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses']
# First few rows:
#           Team  Home wins  Home draws  Home losses
# 0  Real Madrid          0           2            1
# 1    Barcelona          1           2            0
# --------------------------------------------------------------------------------
#
# Table 12:
# Shape: (18, 7)
# Columns: ['Season', 'Round', 'Home team', 'Away team', 'Score\xa0(FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#     Season       Round    Home team    Away team Score (FT/HT)  \
# 0  1988–89   First leg  Real Madrid    Barcelona     2–0 (0–0)
# 1  1988–89  Second leg    Barcelona  Real Madrid     2–1 (1–1)
#
#                      Goals (home)     Goals (away)
# 0  Míchel (51), Hugo Sánchez (78)              NaN
# 1                 Bakero (37, 78)  Butragueño (15)
# --------------------------------------------------------------------------------
#
# Table 13:
# Shape: (10, 5)
# Columns: [0, 1, 2, 3, 4]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 10 Draws 2 Barcelona wins 6 R...
# 1                                   Real Madrid wins
#
#                                                    1    2    3    4
# 0  Team Home wins Home draws Home losses Other ve...  NaN  NaN  NaN
# 1                                                 10  NaN  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 14:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0   1
# 0  Real Madrid wins  10
# 1             Draws   2
# --------------------------------------------------------------------------------
#
# Table 15:
# Shape: (2, 5)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses', 'Other venue wins']
# First few rows:
#           Team  Home wins  Home draws  Home losses  Other venue wins
# 0  Real Madrid          6           1            0                 2
# 1    Barcelona          4           1            2                 2
# --------------------------------------------------------------------------------
#
# Table 16:
# Shape: (1, 8)
# Columns: ['Date', 'Round', 'Stadium', 'Home team', 'Away team', 'Score', 'Goals (home)', 'Goals (away)']
# First few rows:
#                               Date        Round    Stadium    Home team  \
# 0  13 May 1902[16][17][18][19][20]  Semi-finals  Hipódromo  Real Madrid
#
#    Away team Score Goals (home)                  Goals (away)
# 0  Barcelona   1–3  Johnson (?)  Steinberg (?, ?), Gamper (?)
# --------------------------------------------------------------------------------
#
# Table 17:
# Shape: (10, 5)
# Columns: [0, 1, 2, 3, 4]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 0 Draws 0 Barcelona wins 1 Re...
# 1                                   Real Madrid wins
#
#                                                    1    2    3    4
# 0  Team Home wins Home draws Home losses Other ve...  NaN  NaN  NaN
# 1                                                  0  NaN  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 18:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0  1
# 0  Real Madrid wins  0
# 1             Draws  0
# --------------------------------------------------------------------------------
#
# Table 19:
# Shape: (2, 5)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses', 'Other venue wins']
# First few rows:
#           Team  Home wins  Home draws  Home losses  Other venue wins
# 0  Real Madrid          0           0            0                 0
# 1    Barcelona          0           0            0                 1
# --------------------------------------------------------------------------------
#
# Table 20:
# Shape: (8, 8)
# Columns: ['Season', 'Round', 'Round.1', 'Home team', 'Away team', 'Score\xa0(FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#     Season        Round         Round.1    Home team    Away team  \
# 0  1959–60  Semi-finals   First leg[21]  Real Madrid    Barcelona
# 1  1959–60  Semi-finals  Second leg[22]    Barcelona  Real Madrid
#
#   Score (FT/HT)                      Goals (home)                 Goals (away)
# 0     3–1 (2–1)  Di Stéfano (17, 84), Puskás (28)                Martínez (37)
# 1     1–3 (1–1)                       Kocsis (89)  Puskás (25, 75), Gento (68)
# --------------------------------------------------------------------------------
#
# Table 21:
# Shape: (10, 4)
# Columns: [0, 1, 2, 3]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 3 Draws 3 Barcelona wins 2 Re...
# 1                                   Real Madrid wins
#
#                                                    1    2    3
# 0  Team Home wins Home draws Home losses Real Mad...  NaN  NaN
# 1                                                  3  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 22:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0  1
# 0  Real Madrid wins  3
# 1             Draws  3
# --------------------------------------------------------------------------------
#
# Table 23:
# Shape: (2, 4)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses']
# First few rows:
#           Team  Home wins  Home draws  Home losses
# 0  Real Madrid          1           2            1
# 1    Barcelona          1           1            2
# --------------------------------------------------------------------------------
#
# Table 24:
# Shape: (10, 5)
# Columns: [0, 1, 2, 3, 4]
# First few rows:
#                                                    0  \
# 0  Real Madrid wins 105 Draws 52 Barcelona wins 1...
# 1                                   Real Madrid wins
#
#                                                    1    2    3    4
# 0  Team Home wins Home draws Home losses Other ve...  NaN  NaN  NaN
# 1                                                105  NaN  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 25:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0    1
# 0  Real Madrid wins  105
# 1             Draws   52
# --------------------------------------------------------------------------------
#
# Table 26:
# Shape: (2, 5)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses', 'Other venue wins']
# First few rows:
#           Team  Home wins  Home draws  Home losses  Other venue wins
# 0  Real Madrid         68          25           32                 6
# 1    Barcelona         64          27           31                 6
# --------------------------------------------------------------------------------
#
# Table 27:
# Shape: (43, 9)
# Columns: ['Date', 'Tournament', 'Round', 'Stadium', 'Home team', 'Away team', 'Score\xa0(FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#                    Date       Tournament            Round  \
# 0   13 May 1906[30][31]  Exhibition game  Exhibition game
# 1  24 December 1911[32]  Exhibition game  Exhibition game
#
#                     Stadium  Home team    Away team Score (FT/HT)  \
# 0  Camp del carrer Muntaner  Barcelona  Real Madrid           5–2
# 1  L'Escopidora (Industria)  Barcelona  Real Madrid           3–1
#
#                                Goals (home)        Goals (away)
# 0             C. Wallace 2x, Ponz 2x, Forns  Meléndez, Revuelto
# 1  Bernhard Staub (25, 55), Alfredo Massana           Perea (4)
# --------------------------------------------------------------------------------
#
# Table 28:
# Shape: (7, 2)
# Columns: [0, 1]
# First few rows:
#                                                    0    1
# 0  Real Madrid wins 6 Draws 12 Barcelona wins 25 ...  NaN
# 1                                   Real Madrid wins  6.0
# --------------------------------------------------------------------------------
#
# Table 29:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0   1
# 0  Real Madrid wins   6
# 1             Draws  12
# --------------------------------------------------------------------------------
#
# Table 30:
# Shape: (7, 2)
# Columns: [0, 1]
# First few rows:
#                                                    0      1
# 0  Real Madrid wins 111 Draws 64 Barcelona wins 1...    NaN
# 1                                   Real Madrid wins  111.0
# --------------------------------------------------------------------------------
#
# Table 31:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                   0    1
# 0  Real Madrid wins  111
# 1             Draws   64
# --------------------------------------------------------------------------------
#
# Table 32:
# Shape: (41, 7)
# Columns: ['Season[37]', 'Round', 'Home team', 'Away team', 'Score', 'Goals (home)', 'Goals (away)']
# First few rows:
#                       Season[37]                  Round          Home team  \
# 0  1974–75 Copa del Generalísimo  Third round – 1st leg  Barcelona Atlètic
# 1  1974–75 Copa del Generalísimo  Third round – 2nd leg        Castilla CF
#
#            Away team Score Goals (home) Goals (away)
# 0        Castilla CF   2–0          NaN          NaN
# 1  Barcelona Atlètic   3–2          NaN          NaN
# --------------------------------------------------------------------------------
#
# Table 33:
# Shape: (10, 4)
# Columns: [0, 1, 2, 3]
# First few rows:
#                                                    0  \
# 0  Real Madrid Castilla wins 16 Draws 8 Barcelona...
# 1                          Real Madrid Castilla wins
#
#                                                    1    2    3
# 0  Team Home wins Home draws Home losses Real Mad...  NaN  NaN
# 1                                                 16  NaN  NaN
# --------------------------------------------------------------------------------
#
# Table 34:
# Shape: (6, 2)
# Columns: [0, 1]
# First few rows:
#                            0   1
# 0  Real Madrid Castilla wins  16
# 1                      Draws   8
# --------------------------------------------------------------------------------
#
# Table 35:
# Shape: (2, 4)
# Columns: ['Team', 'Home wins', 'Home draws', 'Home losses']
# First few rows:
#                    Team  Home wins  Home draws  Home losses
# 0  Real Madrid Castilla         12           3            4
# 1     Barcelona Atlètic         10           5            4
# --------------------------------------------------------------------------------
#
# Table 36:
# Shape: (4, 8)
# Columns: ['Season', 'Round', 'Round.1', 'Home team', 'Away team', 'Score (FT/HT)', 'Goals (home)', 'Goals (away)']
# First few rows:
#     Season Round     Round.1  Home team  Away team Score (FT/HT)  \
# 0  1980–81   R16   First leg   Castilla  Barcelona     3–5 (1–2)
# 1  1980–81   R16  Second leg  Barcelona   Castilla     4–1 (2–0)
#
#                                   Goals (home)  \
# 0           Ortiz (9), Paco, (51), Blanco (57)
# 1  Quini (3, 47), Esteban (15), Landáburu (89)
#
#                                         Goals (away)
# 0  Landáburu (5), Quini (13), Zuviría (65), Migue...
# 1                                          Paco (55)
# --------------------------------------------------------------------------------
#
# Table 37:
# Shape: (8, 2)
# Columns: ['vteFutbol Club Barcelona', 'vteFutbol Club Barcelona.1']
# First few rows:
#                             vteFutbol Club Barcelona  \
# 0  History Academy (La Masia) Players Managers Pr...
# 1                                        Other teams
#
#                           vteFutbol Club Barcelona.1
# 0  History Academy (La Masia) Players Managers Pr...
# 1  FC Barcelona Atlètic FC Barcelona Femení FC Ba...
# --------------------------------------------------------------------------------
#
# Table 38:
# Shape: (12, 2)
# Columns: ['vteReal Madrid Club de Fútbol', 'vteReal Madrid Club de Fútbol.1']
# First few rows:
#                        vteReal Madrid Club de Fútbol  \
# 0  History Players Managers Presidents Seasons In...
# 1                                   Culture and lore
#
#                      vteReal Madrid Club de Fútbol.1
# 0  History Players Managers Presidents Seasons In...
# 1  Yé-yé La Quinta del Buitre Galácticos Real, Th...
# --------------------------------------------------------------------------------
#
# Table 39:
# Shape: (1, 2)
# Columns: ['vteSpanish football rivalries', 'vteSpanish football rivalries.1']
# First few rows:
#                        vteSpanish football rivalries  \
# 0  Aragonese derby Asturian derby Athletic–Barcel...
#
#                      vteSpanish football rivalries.1
# 0  Aragonese derby Asturian derby Athletic–Barcel...
# --------------------------------------------------------------------------------
